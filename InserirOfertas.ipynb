# %%
import pandas as pd 

ofertadados = pd.read_csv("Documents/dados/portfolio_ofertas - portfolio_ofertas.csv")
eventosdados = pd.read_csv("Documents/dados/eventos_ofertas.csv",encoding="latin1")

eventosdados = eventosdados.loc[eventosdados["cliente"].notnull()]

# %%
ofertadados
# Out:
#    Unnamed: 0  recompensa                                 canal  valor_minimo  \
# 0           1          10         ['email', 'mobile', 'social']            10
# 1           2          10  ['web', 'email', 'mobile', 'social']            10
# 2           3           0            ['web', 'email', 'mobile']             0
# 3           4           5            ['web', 'email', 'mobile']             5
# 4           5           5                      ['web', 'email']            20
# 5           6           3  ['web', 'email', 'mobile', 'social']             7
# 6           7           2  ['web', 'email', 'mobile', 'social']            10
# 7           8           0         ['email', 'mobile', 'social']             0
# 8           9           5  ['web', 'email', 'mobile', 'social']             5
# 9          10           2            ['web', 'email', 'mobile']            10
#
#    duracao                                id            oferta
# ...

# %%
filtrorecompensa = eventosdados.loc[eventosdados["recompensa"].notnull()]

# %%
filtrorecompensa.loc[filtrorecompensa["valor"].isnull(),"valor"]
# Out:
#         Unnamed: 0                           cliente  tempo_decorrido  valor  \
# 12658        12659  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f                0    NaN
# 12672        12673  fe97aa22dd3e48c8b143116a8403dd52                0    NaN
# 12679        12680  629fc02d56414d91bca360decdfa9288                0    NaN
# 12692        12693  676506bad68e4161b9bbaffeb039626b                0    NaN
# 12697        12698  8f7dd3b2afe14c078eb4f6e6fe4ba97d                0    NaN
# ...            ...                               ...              ...    ...
# 306475      306476  0c027f5f34dd4b9eba0a25785c611273              714    NaN
# 306497      306498  a6f84f4e976f44508c358cc9aba6d2b3              714    NaN
# 306506      306507  b895c57e8cd047a8872ce02aa54759d6              714    NaN
# 306509      306510  8431c16f8e1d440880db371a68f82dd0              714    NaN
# 306527      306528  24f56b5e1849462093931b164eb803b5              714    NaN
#
# ...
